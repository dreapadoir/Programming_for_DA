# %% [markdown]
# # Testing matplotlib output in Jupyter notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
list = np.arange(-10,10,0.1)
ran = np.arange(0, 300, 0.3)
plt.plot(list, list**3, list, list**2)
plt.show()
